# %% [markdown]
# <a href="https://colab.research.google.com/github/housekjh1/study-pandas/blob/main/1026_Chap7%2C10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
neighborhoods = pd.read_csv("neighborhoods.csv",
                            index_col = [0,1,2],
                            header = [0,1]
                            )
neighborhoods.columns.names = ["Category", "Subcategory"]
neighborhoods
# Out:
# Category                                       Culture         Services  \
# Subcategory                                Restaurants Museums   Police
# State City               Street
# MO    Fisherborough      244 Tracy View             C+       F       D-
# SD    Port Curtisville   446 Cynthia Inlet          C-       B        B
# WV    Jimenezview        432 John Common             A      A+        F
# AK    Stevenshire        238 Andrew Rue             D-       A       A-
# ND    New Joshuaport     877 Walter Neck            D+      C-        B
# ...                                                ...     ...      ...
# MI    North Matthew      055 Clayton Isle           B-       C        B
# MT    Chadton            601 Richards Road          A-       D       D+
# SC    Diazmouth          385 Robin Harbors           F       D       B-
# VA    Laurentown         255 Gonzalez Land          C+      B-        F
# NE    South Kennethmouth 346 Wallace Pass           C-      B-        A
# ...

# %%
neighborhoods.sort_index(ascending=[True, False, True]).head()
# Out:
# Category                                     Culture         Services
# Subcategory                              Restaurants Museums   Police Schools
# State City           Street
# AK    Stevenshire    238 Andrew Rue               D-       A       A-      A-
#       Scottstad      082 Leblanc Freeway           D      C-        D      B+
#                      114 Jones Garden             D-      D-        D       D
#       Rowlandchester 386 Rebecca Cove             C-      A-       A+       C
# AL    Vegaside       191 Mindy Meadows            B+      A-       A+      D+

# %%
data = [
    [1,2],
    [3,4]
]
df = pd.DataFrame(data=data,
                  index = ["A", "B"],
                  columns = ["X", "Y"]
                  )
df
# Out:
#    X  Y
# A  1  2
# B  3  4

# %%
df["X"]
# Out:
# A    1
# B    3
# Name: X, dtype: int64

# %%
neighborhoods["Services"]
# Out:
# Subcategory                                Police Schools
# State City               Street
# MO    Fisherborough      244 Tracy View        D-      A+
# SD    Port Curtisville   446 Cynthia Inlet      B      D+
# WV    Jimenezview        432 John Common        F       B
# AK    Stevenshire        238 Andrew Rue        A-      A-
# ND    New Joshuaport     877 Walter Neck        B       B
# ...                                           ...     ...
# MI    North Matthew      055 Clayton Isle       B      C+
# MT    Chadton            601 Richards Road     D+       D
# SC    Diazmouth          385 Robin Harbors     B-      D+
# VA    Laurentown         255 Gonzalez Land      F      D-
# NE    South Kennethmouth 346 Wallace Pass       A      A-
#
# [251 rows x 2 columns]

# %%
neighborhoods[("Services", "Schools")]
# Out:
# State  City                Street
# MO     Fisherborough       244 Tracy View       A+
# SD     Port Curtisville    446 Cynthia Inlet    D+
# WV     Jimenezview         432 John Common       B
# AK     Stevenshire         238 Andrew Rue       A-
# ND     New Joshuaport      877 Walter Neck       B
#                                                 ..
# MI     North Matthew       055 Clayton Isle     C+
# MT     Chadton             601 Richards Road     D
# SC     Diazmouth           385 Robin Harbors    D+
# VA     Laurentown          255 Gonzalez Land    D-
# NE     South Kennethmouth  346 Wallace Pass     A-
# Name: (Services, Schools), Length: 251, dtype: object

# %%
neighborhoods[[("Services", "Schools"),
               ("Culture", "Museums")]]
# Out:
# Category                                   Services Culture
# Subcategory                                 Schools Museums
# State City               Street
# MO    Fisherborough      244 Tracy View          A+       F
# SD    Port Curtisville   446 Cynthia Inlet       D+       B
# WV    Jimenezview        432 John Common          B      A+
# AK    Stevenshire        238 Andrew Rue          A-       A
# ND    New Joshuaport     877 Walter Neck          B      C-
# ...                                             ...     ...
# MI    North Matthew      055 Clayton Isle        C+       C
# MT    Chadton            601 Richards Road        D       D
# SC    Diazmouth          385 Robin Harbors       D+       D
# VA    Laurentown         255 Gonzalez Land       D-      B-
# NE    South Kennethmouth 346 Wallace Pass        A-      B-
#
# [251 rows x 2 columns]

# %%
df.loc["A"]
# Out:
# X    1
# Y    2
# Name: A, dtype: int64

# %%
df.iloc[1]
# Out:
# X    3
# Y    4
# Name: B, dtype: int64

# %%
neighborhoods.loc[("MO", "Fisherborough", "244 Tracy View")]
# Out:
# Category  Subcategory
# Culture   Restaurants    C+
#           Museums         F
# Services  Police         D-
#           Schools        A+
# Name: (MO, Fisherborough, 244 Tracy View), dtype: object

# %%
neighborhoods.loc["CA"]
# Out:
# Category                              Culture         Services
# Subcategory                       Restaurants Museums   Police Schools
# City           Street
# Dustinmouth    793 Cynthia Square          A-      A+       C-       A
# Ryanfort       934 David Run                F      B+        F      D-
# North Jennifer 303 Alisha Road             D-      C+       C+      A+

# %%
neighborhoods.loc["CA", ("Services", "Schools")]
# Out:
# City            Street
# Dustinmouth     793 Cynthia Square     A
# Ryanfort        934 David Run         D-
# North Jennifer  303 Alisha Road       A+
# Name: (Services, Schools), dtype: object

# %%
neighborhoods.iloc[[25,30]]
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City               Street
# UT    North Kennethmouth 208 Regina Roads          D-      A+       A+       B
# DE    New Janice         417 Simmons Spur           A       A        F      C-

# %%
neighborhoods.iloc[25:31]
# Out:
# Category                                        Culture         Services  \
# Subcategory                                 Restaurants Museums   Police
# State City               Street
# UT    North Kennethmouth 208 Regina Roads            D-      A+       A+
# MD    Richardland        695 Amy Ports               D+      C+       D+
# ND    Davidshire         035 Trevor Squares           C       D        C
# FL    Jacksonfort        369 Victoria Road           D-      D+        A
# NM    West Ambermouth    785 Kristen Vista           D-      D-       D+
# DE    New Janice         417 Simmons Spur             A       A        F
#
# Category
# Subcategory                                 Schools
# State City               Street
# UT    North Kennethmouth 208 Regina Roads         B
# MD    Richardland        695 Amy Ports            D
# ND    Davidshire         035 Trevor Squares      D+
# FL    Jacksonfort        369 Victoria Road        D
# ...

# %%
neighborhoods.xs(axis = "columns", key = "Museums", level = "Subcategory")
# Out:
# Category                                   Culture
# State City               Street
# MO    Fisherborough      244 Tracy View          F
# SD    Port Curtisville   446 Cynthia Inlet       B
# WV    Jimenezview        432 John Common        A+
# AK    Stevenshire        238 Andrew Rue          A
# ND    New Joshuaport     877 Walter Neck        C-
# ...                                            ...
# MI    North Matthew      055 Clayton Isle        C
# MT    Chadton            601 Richards Road       D
# SC    Diazmouth          385 Robin Harbors       D
# VA    Laurentown         255 Gonzalez Land      B-
# NE    South Kennethmouth 346 Wallace Pass       B-
#
# [251 rows x 1 columns]

# %% [markdown]
# ---
# ## 연습 문제

# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("customers.csv")
customers.head()
# Out:
#                   Name                                            Address
# 0        Frank Manning  6461 Quinn Groves, East Matthew, New Hampshire...
# 1    Elizabeth Johnson  1360 Tracey Ports Apt. 419, Kyleport, Vermont,...
# 2      Donald Stephens  19120 Fleming Manors, Prestonstad, Montana, 23495
# 3  Michael Vincent III       441 Olivia Creek, Jimmymouth, Georgia, 82991
# 4       Jasmine Zamora  4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...

# %%
customers["Address"].str.split(",", expand=True)
# Out:
#                                0              1               2       3
# 0              6461 Quinn Groves   East Matthew   New Hampshire   16656
# 1     1360 Tracey Ports Apt. 419       Kyleport         Vermont   31924
# 2           19120 Fleming Manors    Prestonstad         Montana   23495
# 3               441 Olivia Creek     Jimmymouth         Georgia   82991
# 4     4246 Chelsey Ford Apt. 310      Karamouth            Utah   76252
# ...                          ...            ...             ...     ...
# 9956   762 Andrew Views Apt. 254     North Paul      New Mexico   28889
# 9957    44188 Day Crest Apt. 901    Lake Marcia           Maine   37378
# 9958      73015 Michelle Squares    Watsonville   West Virginia   03933
# 9959            129 Keith Greens      Haleyfurt        Oklahoma   98916
# 9960          355 Griffin Valley      Davidtown      New Mexico   17581
#
# [9961 rows x 4 columns]

# %%
customers["Street"] = customers["Address"].str.split(",", expand=True)[0]
customers["City"] = customers["Address"].str.split(",", expand=True)[1]
customers["State"] = customers["Address"].str.split(",", expand=True)[2]
customers["Zip"] = customers["Address"].str.split(",", expand=True)[3]
customers
# Out:
#                      Name                                            Address  \
# 0           Frank Manning  6461 Quinn Groves, East Matthew, New Hampshire...
# 1       Elizabeth Johnson  1360 Tracey Ports Apt. 419, Kyleport, Vermont,...
# 2         Donald Stephens  19120 Fleming Manors, Prestonstad, Montana, 23495
# 3     Michael Vincent III       441 Olivia Creek, Jimmymouth, Georgia, 82991
# 4          Jasmine Zamora  4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...
# ...                   ...                                                ...
# 9956        Dana Browning  762 Andrew Views Apt. 254, North Paul, New Mex...
# 9957      Amanda Anderson  44188 Day Crest Apt. 901, Lake Marcia, Maine, ...
# 9958           Eric Davis  73015 Michelle Squares, Watsonville, West Virg...
# 9959     Taylor Hernandez       129 Keith Greens, Haleyfurt, Oklahoma, 98916
# 9960     Sherry Nicholson   355 Griffin Valley, Davidtown, New Mexico, 17581
#
# ...

# %%
new_cols = ["Street", "City", "State", "Zip"]
customers[new_cols] = customers["Address"].str.split(",", expand=True)
customers
# Out:
#                      Name                                            Address  \
# 0           Frank Manning  6461 Quinn Groves, East Matthew, New Hampshire...
# 1       Elizabeth Johnson  1360 Tracey Ports Apt. 419, Kyleport, Vermont,...
# 2         Donald Stephens  19120 Fleming Manors, Prestonstad, Montana, 23495
# 3     Michael Vincent III       441 Olivia Creek, Jimmymouth, Georgia, 82991
# 4          Jasmine Zamora  4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...
# ...                   ...                                                ...
# 9956        Dana Browning  762 Andrew Views Apt. 254, North Paul, New Mex...
# 9957      Amanda Anderson  44188 Day Crest Apt. 901, Lake Marcia, Maine, ...
# 9958           Eric Davis  73015 Michelle Squares, Watsonville, West Virg...
# 9959     Taylor Hernandez       129 Keith Greens, Haleyfurt, Oklahoma, 98916
# 9960     Sherry Nicholson   355 Griffin Valley, Davidtown, New Mexico, 17581
#
# ...

# %% [markdown]
# ---

# %%
investments = pd.read_csv("investments.csv")
investments
# Out:
#                      Name               Market     Status State  \
# 0                #waywire                 News   Acquired    NY
# 1      &TV Communications                Games  Operating    CA
# 2      -R- Ranch and Mine              Tourism  Operating    TX
# 3        004 Technologies             Software  Operating    IL
# 4                 1-4 All             Software  Operating    NC
# ...                   ...                  ...        ...   ...
# 27794               Zynga           Technology  Operating    CA
# 27795            Zyngenia        Biotechnology  Operating    MD
# 27796              ZYOMYX        Biotechnology  Operating    MO
# 27797               Zyrra           E-Commerce  Operating    MA
# 27798               [x+1]  Enterprise Software  Operating    NY
#
#        Funding Rounds
# 0                   1
# 1                   2
# 2                   2
# 3                   1
# 4                   1
# ...               ...
# 27794               9
# ...

# %%
investments.nunique()
# Out:
# Name              27763
# Market              693
# Status                3
# State                61
# Funding Rounds       16
# dtype: int64

# %%
investments = investments.set_index(keys = ["Status", "Funding Rounds", "State"]).sort_index()
investments
# Out:
#                                                       Name  \
# Status    Funding Rounds State
# Acquired  1              AB                 Hallpass Media
#                          AL                      EnteGreat
#                          AL       Onward Behavioral Health
#                          AL                        Proxsys
#                          AZ                    Envox Group
# ...                                                    ...
# Operating 14             CA                   CNS Response
#                          TN     Covenant Surgical Partners
#           15             MA                      Terascala
#                          PA                       InstaMed
#           18             CA      Solarflare Communications
#
#                                              Market
# Status    Funding Rounds State
# Acquired  1              AB                   Games
#                          AL     Enterprise Software
# ...

# %%
investments.loc[("Closed",)]
# Out:
#                                              Name                Market
# Funding Rounds State
# 1              AB     Cardinal Media Technologies  Social Network Media
#                AB                Easy Bill Online              Tracking
#                AB                   Globel Direct      Public Relations
#                AB               Ph03nix New Media                 Games
#                AL                           Naubo                  News
# ...                                           ...                   ...
# 8              GA                        MedShape           Health Care
#                NC             Biolex Therapeutics         Biotechnology
#                WA                      Cozi Group     Online Scheduling
# 9              NY         Blackaeon International              Robotics
# 11             OR                          Lecere              Software
#
# [1498 rows x 2 columns]

# %%
investments.loc[("Acquired",10)]
# Out:
#                    Name       Market
# State
# NY     Genesis Networks  Web Hosting
# TX       ACTIVE Network     Software

# %%
investments.loc[("Operating",6,"NJ")]
# Out:
#                                               Name             Market
# Status    Funding Rounds State
# Operating 6              NJ     Agile Therapeutics      Biotechnology
#                          NJ               Agilence  Retail Technology
#                          NJ      Edge Therapeutics      Biotechnology
#                          NJ                Nistica        Web Hosting

# %%
investments.loc[("Closed",8), ("Name",)]
# Out:
#                       Name
# State
# CA               CipherMax
# CA      Dilithium Networks
# CA                 Moblyng
# CA                SolFocus
# CA                Solyndra
# FL     Extreme Enterprises
# GA                MedShape
# NC     Biolex Therapeutics
# WA              Cozi Group

# %%
investments.xs(axis = "rows", key = "NJ", level = "State")
# Out:
#                                               Name               Market
# Status    Funding Rounds
# Acquired  1                                  AkaRx        Biotechnology
#           1                         Aptalis Pharma        Biotechnology
#           1                                 Cadent             Software
#           1                        Cancer Genetics  Health And Wellness
#           1                              Clacendix           E-Commerce
# ...                                            ...                  ...
# Operating 6                                Nistica          Web Hosting
#           7               Cyclacel Pharmaceuticals        Biotechnology
#           7                       PTC Therapeutics          Health Care
#           8                 Svelte Medical Systems          Health Care
#           11                                 Vidyo            Messaging
#
# [512 rows x 2 columns]

# %%
investments = investments.reset_index()
investments
# Out:
#           Status  Funding Rounds State                        Name  \
# 0       Acquired               1    AB              Hallpass Media
# 1       Acquired               1    AL                   EnteGreat
# 2       Acquired               1    AL    Onward Behavioral Health
# 3       Acquired               1    AL                     Proxsys
# 4       Acquired               1    AZ                 Envox Group
# ...          ...             ...   ...                         ...
# 27794  Operating              14    CA                CNS Response
# 27795  Operating              14    TN  Covenant Surgical Partners
# 27796  Operating              15    MA                   Terascala
# 27797  Operating              15    PA                    InstaMed
# 27798  Operating              18    CA   Solarflare Communications
#
#                     Market
# 0                    Games
# 1      Enterprise Software
# 2            Biotechnology
# 3            Biotechnology
# ...

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np

# %%
groups1 = pd.read_csv("meetup/groups1.csv")
groups1.head(2)
# Out:
#    group_id                       name  category_id  city_id
# 0      6388     Alternative Health NYC           14    10001
# 1      6510  Alternative Energy Meetup            4    10001

# %%
groups2 = pd.read_csv("meetup/groups2.csv")
groups2.head(2)
# Out:
#    group_id                                               name  category_id  \
# 0  18879327                                       BachataMania            5
# 1  18880221  Photoshoot Chicago - Photography and Modeling ...           27
#
#    city_id
# 0    10001
# 1    60601

# %%
categories = pd.read_csv("meetup/categories.csv")
categories.head(2)
# Out:
#    category_id       category_name
# 0            1      Arts & Culture
# 1            3  Cars & Motorcycles

# %%
cities = pd.read_csv("meetup/cities.csv", dtype={"zip":"string"})
cities.head(2)
# Out:
#       id           city state    zip
# 0   7093  West New York    NJ  07093
# 1  10001       New York    NY  10001

# %%
groups = pd.concat(objs = [groups1, groups2], ignore_index=True)

# %%
groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16330 entries, 0 to 16329
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   group_id     16330 non-null  int64
#  1   name         16329 non-null  object
#  2   category_id  16330 non-null  int64
#  3   city_id      16330 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 510.4+ KB

# %%
categories.head(2)
# Out:
#    category_id       category_name
# 0            1      Arts & Culture
# 1            3  Cars & Motorcycles

# %%
groups.merge(categories)
# Out:
#       group_id                                        name  category_id  \
# 0         6388                      Alternative Health NYC           14
# 1        54126                          Energy Healers NYC           14
# 2        67776                     Flourishing Life Meetup           14
# 3       111855      Hypnosis & NLP NYC - Update Your Brain           14
# 4       129277             The Live Food Chicago Community           14
# ...        ...                                         ...          ...
# 8032  25536270       New York Cuckold Relationships Meetup           17
# 8033  25795045  Pagans Paradise NYC - A Haven for Heathens           17
# 8034  25856573                 Fuck Yeah Femme Productions           17
# 8035  26158102                 Chicago Crossdresser Meetup           17
# 8036  26219043                    Corporate Goes Conscious           17
#
#       city_id       category_name
# 0       10001  Health & Wellbeing
# ...

# %%
groups.merge(categories, how = "left", on = "category_id")
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id            category_name
# 0               14    10001       Health & Wellbeing
# 1                4    10001  Community & Environment
# ...

# %%
groups.merge(categories, how = "inner", on = "category_id")
# Out:
#       group_id                                        name  category_id  \
# 0         6388                      Alternative Health NYC           14
# 1        54126                          Energy Healers NYC           14
# 2        67776                     Flourishing Life Meetup           14
# 3       111855      Hypnosis & NLP NYC - Update Your Brain           14
# 4       129277             The Live Food Chicago Community           14
# ...        ...                                         ...          ...
# 8032  25536270       New York Cuckold Relationships Meetup           17
# 8033  25795045  Pagans Paradise NYC - A Haven for Heathens           17
# 8034  25856573                 Fuck Yeah Femme Productions           17
# 8035  26158102                 Chicago Crossdresser Meetup           17
# 8036  26219043                    Corporate Goes Conscious           17
#
#       city_id       category_name
# 0       10001  Health & Wellbeing
# ...

# %%
groups.merge(categories, how = "outer", on = "category_id")
# Out:
#          group_id                                               name  \
# 0          6388.0                             Alternative Health NYC
# 1         54126.0                                 Energy Healers NYC
# 2         67776.0                            Flourishing Life Meetup
# 3        111855.0             Hypnosis & NLP NYC - Update Your Brain
# 4        129277.0                    The Live Food Chicago Community
# ...           ...                                                ...
# 16326  26305466.0  Art Collision: Fighting Human Trafficking Thro...
# 16327  26320310.0                             New York Makeup Meetup
# 16328  26347935.0                                       Makeup Babes
# 16329  26353516.0                             Wear with Flare Meetup
# 16330         NaN                                                NaN
#
#        category_id  city_id       category_name
# 0               14  10001.0  Health & Wellbeing
# ...

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np

# %%
# !pip install finance-DataReader

# %%
import FinanceDataReader as fdr
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = fdr.DataReader("AAPL", "2023")

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.538658
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.823189
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.488876
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  129.069321
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.597061
#
#                Volume
# Date
# 2023-01-03  112117500
# 2023-01-04   89113600
# 2023-01-05   80962700
# 2023-01-06   87754700
# 2023-01-09   70790800

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-10-19  176.039993  177.839996  175.190002  175.460007  175.460007
# 2023-10-20  175.309998  175.419998  172.639999  172.880005  172.880005
# 2023-10-23  170.910004  174.009995  169.929993  173.000000  173.000000
# 2023-10-24  173.050003  173.669998  171.449997  173.440002  173.440002
# 2023-10-25  171.880005  173.059998  170.649994  171.100006  171.100006
#
#               Volume
# Date
# 2023-10-19  59302900
# 2023-10-20  64189300
# 2023-10-23  55980100
# 2023-10-24  43816600
# 2023-10-25  56939400

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df.index, y=df["Close"])
plt.show()

# %%
df_month = df.resample("BM").mean()
df_month.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-31  135.126000  137.271499  133.737001  135.778999  135.202165
# 2023-02-28  150.226316  152.296842  149.011581  150.968421  150.471768
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.542043
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.595553
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.293533
#
#                   Volume
# Date
# 2023-01-31  7.218262e+07
# 2023-02-28  6.879994e+07
# 2023-03-31  6.609855e+07
# 2023-04-28  5.103735e+07
# 2023-05-31  5.796161e+07

# %%
df_month['RTN']=df_month['Close'].pct_change()*100
df_month.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-31  135.126000  137.271499  133.737001  135.778999  135.202165
# 2023-02-28  150.226316  152.296842  149.011581  150.968421  150.471768
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.542043
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.595553
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.293533
#
#                   Volume        RTN
# Date
# 2023-01-31  7.218262e+07        NaN
# 2023-02-28  6.879994e+07  11.186871
# 2023-03-31  6.609855e+07   2.647150
# 2023-04-28  5.103735e+07   6.505354
# 2023-05-31  5.796161e+07   4.590809

# %%
df_month['MA']=df_month['Close'].rolling(2).mean()
df_month.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-31  135.126000  137.271499  133.737001  135.778999  135.202165
# 2023-02-28  150.226316  152.296842  149.011581  150.968421  150.471768
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.542043
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.595553
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.293533
#
#                   Volume        RTN          MA
# Date
# 2023-01-31  7.218262e+07        NaN         NaN
# 2023-02-28  6.879994e+07  11.186871  143.373710
# 2023-03-31  6.609855e+07   2.647150  152.966601
# 2023-04-28  5.103735e+07   6.505354  160.005286
# 2023-05-31  5.796161e+07   4.590809  168.834259
