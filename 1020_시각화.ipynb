# %% [markdown]
# <a href="https://colab.research.google.com/github/housekjh1/study-pandas/blob/main/1020_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
space = pd.read_csv("space_missions.csv", parse_dates=["Date"], index_col="Date")
space.head()
# Out:
#            Company Name Location    Cost   Status
# Date
# 2019-02-05  Arianespace   France  200.00  Success
# 2019-02-22       SpaceX      USA   50.00  Success
# 2019-03-02       SpaceX      USA   50.00  Success
# 2019-03-09         CASC    China   29.15  Success
# 2019-03-22  Arianespace   France   37.00  Success

# %%
space["Cost"].plot(kind="line") # X축 기본값은 인덱스, Y축은 컬럼값
# Out:
# <Axes: xlabel='Date'>

# %%
space.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2019-02-05 to 2020-08-07
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  120 non-null    object
#  1   Location      120 non-null    object
#  2   Cost          120 non-null    float64
#  3   Status        120 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 4.7+ KB

# %%
space.plot() # X, Y축은 숫자만 가능, Y축은 숫자형 데이터를 사용, 범례(레전드) 참조
# Out:
# <Axes: xlabel='Date'>

# %%
data = [[2000,3000000],[5000,5000000]]
df = pd.DataFrame(data = data, columns=["Small", "Large"])
df
# Out:
#    Small    Large
# 0   2000  3000000
# 1   5000  5000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
space.plot(y="Cost", colormap="gray")
# Out:
# <Axes: xlabel='Date'>

# %%
space["Company Name"].value_counts().plot(kind="bar") # 막대는 무조건 0부터 시작, 선형은 잘라도 됨
# Out:
# <Axes: >

# %%
space["Company Name"].value_counts().plot(kind="barh")
# Out:
# <Axes: >
